# %%
import pandas as pd

# %%
links = pd.read_csv('links.csv')
links
# Out:
#       Unnamed: 0                    track1              artist1  \
# 0              0              Love II Love               Damage
# 1              1              Love II Love               Damage
# 2              2              Love II Love               Damage
# 3              3              Love II Love               Damage
# 4              4              Love II Love               Damage
# ...          ...                       ...                  ...
# 4945        4945                      Floe         Philip Glass
# 4946        4946                      Floe         Philip Glass
# 4947        4947  Come A Little Bit Closer  Jay & The Americans
# 4948        4948  Come A Little Bit Closer  Jay & The Americans
# 4949        4949   The Fruit That Got Away         David Rovics
#
#                                                  track2               artist2  \
# 0                                    Darkness and Death                Watain
# ...

# %%
links.describe(percentiles=[.01, .05, .1, .15])
# Out:
#         Unnamed: 0    euclidean
# count  4950.000000  4950.000000
# mean   2474.500000     0.621917
# std    1429.086247     0.292036
# min       0.000000     0.047269
# 1%       49.490000     0.121576
# 5%      247.450000     0.206442
# 10%     494.900000     0.259790
# 15%     742.350000     0.308672
# 50%    2474.500000     0.599112
# max    4949.000000     1.472094

# %%
link = links[links["euclidean"]  < 0.389349]
link
# Out:
#       Unnamed: 0            track1       artist1  \
# 1              1      Love II Love        Damage
# 5              5      Love II Love        Damage
# 6              6      Love II Love        Damage
# 7              7      Love II Love        Damage
# 9              9      Love II Love        Damage
# ...          ...               ...           ...
# 4929        4929   Always Together    Al Martino
# 4931        4931   Always Together    Al Martino
# 4940        4940  Pimpolho Moderno      Ary Lobo
# 4941        4941  Pimpolho Moderno      Ary Lobo
# 4944        4944              Floe  Philip Glass
#
#                                   track2                 artist2  euclidean
# 1                                   Gold     Ton Steine Scherben   0.252674
# 5                    The Way You Love Me             Karyn White   0.106916
# 6                                Do I Do           Stevie Wonder   0.207349
# ...

# %%
link.describe()
# Out:
#         Unnamed: 0    euclidean
# count  1237.000000  1237.000000
# mean   2424.332255     0.273628
# std    1421.164137     0.078674
# min       1.000000     0.047269
# 25%    1147.000000     0.218869
# 50%    2420.000000     0.285397
# 75%    3610.000000     0.338784
# max    4944.000000     0.389309
